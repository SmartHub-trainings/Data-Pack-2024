# %%
file =open("../datasets/bank-additional/bank-additional-names.txt")
print(file.read())
# Out:
# ﻿Citation Request:
#   This dataset is publicly available for research. The details are described in [Moro et al., 2014].
#   Please include this citation if you plan to use this database:
#
#   [Moro et al., 2014] S. Moro, P. Cortez and P. Rita. A Data-Driven Approach to Predict the Success of Bank Telemarketing. Decision Support Systems, In press, http://dx.doi.org/10.1016/j.dss.2014.03.001
#
#   Available at: [pdf] http://dx.doi.org/10.1016/j.dss.2014.03.001
#                 [bib] http://www3.dsi.uminho.pt/pcortez/bib/2014-dss.txt
#
# 1. Title: Bank Marketing (with social/economic context)
#
# 2. Sources
#    Created by: Sérgio Moro (ISCTE-IUL), Paulo Cortez (Univ. Minho) and Paulo Rita (ISCTE-IUL) @ 2014
#
# 3. Past Usage:
#
#   The full dataset (bank-additional-full.csv) was described and analyzed in:
#
#   S. Moro, P. Cortez and P. Rita. A Data-Driven Approach to Predict the Success of Bank Telemarketing. Decision Support Systems (2014), doi:10.1016/j.dss.2014.03.001.
#
# ...

# %%
import pandas as pd

# %%
bank_full=pd.read_csv("../datasets/bank-additional/bank-additional-full.csv",sep=";")

# %%
bank_full.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
bank_full.shape
# Out:
# (41188, 21)

# %%
pd.get_dummies(bank_full,columns=["marital","job"],drop_first=True,).head()
# Out:
#    age    education  default housing loan    contact month day_of_week  \
# 0   56     basic.4y       no      no   no  telephone   may         mon
# 1   57  high.school  unknown      no   no  telephone   may         mon
# 2   37  high.school       no     yes   no  telephone   may         mon
# 3   40     basic.6y       no      no   no  telephone   may         mon
# 4   56  high.school       no      no  yes  telephone   may         mon
#
#    duration  campaign  ...  job_entrepreneur  job_housemaid job_management  \
# 0       261         1  ...                 0              1              0
# 1       149         1  ...                 0              0              0
# 2       226         1  ...                 0              0              0
# 3       151         1  ...                 0              0              0
# 4       307         1  ...                 0              0              0
#
#    job_retired  job_self-employed  job_services  job_student  job_technician  \
# ...

# %%
bank_full.marital=bank_full.marital.astype("category")

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_48092/413525391.py in <module>
# ----> 1 pd.get_dummies(bank_full,dtype="category")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     934         for (col, pre, sep) in zip(data_to_encode.items(), prefix, prefix_sep):
#     935             # col is (column_name, column), use just column data here
# --> 936             dummy = _get_dummies_1d(
#     937                 col[1],
#     938                 prefix=pre,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/reshape.py in _get_dummies_1d(data, prefix, prefix_sep, dummy_na, sparse, drop_first, dtype)
# ...

# %%
bank_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
bank_full.memory_usage().sum()/1e6
# Out:
# 6.919712

# %%
bank_full.memory_usage(deep=True).sum()/1e6
# Out:
# 31.730891

# %%
bank=pd.read_csv("../datasets/bank-additional/bank-additional.csv",sep=";")

# %%
bank.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_10657/3059852991.py in <module>
# ----> 1 bank_full.unique()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
pd.unique(bank_full.marital)
# Out:
# array(['married', 'single', 'divorced', 'unknown'], dtype=object)

# %%
bank_full.marital=bank_full.marital.astype("category")

# %%
bank_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  category
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
bank_full.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
for name in bank_full.columns:
    uniq=pd.unique(bank_full[name])
#     print(name)
#     print(uniq)
#     print(bank_full[name].dtype)
#     print()
    if len(uniq)/bank_full.shape[0]<0.3 and  bank_full[name].dtype=="object":
        bank_full[name]=bank_full[name].astype("category")
# Out:
# age
# [56 57 37 40 45 59 41 24 25 29 35 54 46 50 39 30 55 49 34 52 58 32 38 44
#  42 60 53 47 51 48 33 31 43 36 28 27 26 22 23 20 21 61 19 18 70 66 76 67
#  73 88 95 77 68 75 63 80 62 65 72 82 64 71 69 78 85 79 83 81 74 17 87 91
#  86 98 94 84 92 89]
# int64
#
# job
# ['housemaid' 'services' 'admin.' 'blue-collar' 'technician' 'retired'
#  'management' 'unemployed' 'self-employed' 'unknown' 'entrepreneur'
#  'student']
# object
#
# marital
# ['married' 'single' 'divorced' 'unknown']
# object
#
# education
# ['basic.4y' 'high.school' 'basic.6y' 'basic.9y' 'professional.course'
#  'unknown' 'university.degree' 'illiterate']
# object
#
# default
# ['no' 'unknown' 'yes']
# object
#
# housing
# ['no' 'yes' 'unknown']
# object
#
# loan
# ['no' 'yes' 'unknown']
# object
#
# contact
# ['telephone' 'cellular']
# object
#
# month
# ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'mar' 'apr' 'sep']
# object
#
# day_of_week
# ['mon' 'tue' 'wed' 'thu' 'fri']
# object
#
# duration
# ...

# %%
bank_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  category
#  2   marital         41188 non-null  category
#  3   education       41188 non-null  category
#  4   default         41188 non-null  category
#  5   housing         41188 non-null  category
#  6   loan            41188 non-null  category
#  7   contact         41188 non-null  category
#  8   month           41188 non-null  category
#  9   day_of_week     41188 non-null  category
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  category
#  15  emp.var.rate    41188 non-null  float64
# ...

# %%
bank_full.memory_usage()
# Out:
# Index                128
# age               329504
# job                41584
# marital            41392
# education          41552
# default            41320
# housing            41320
# loan               41320
# contact            41312
# month              41568
# day_of_week        41400
# duration          329504
# campaign          329504
# pdays             329504
# previous          329504
# poutcome           41320
# emp.var.rate      329504
# cons.price.idx    329504
# cons.conf.idx     329504
# euribor3m         329504
# nr.employed       329504
# y                  41312
# dtype: int64

# %%
bank_full.memory_usage().sum()/1e6
# Out:
# 3.750568

# %%
bank_full.memory_usage(deep=True)
# Out:
# Index                128
# age               329504
# job                42282
# marital            41616
# education          42032
# default            41479
# housing            41479
# loan               41479
# contact            41427
# month              42088
# day_of_week        41660
# duration          329504
# campaign          329504
# pdays             329504
# previous          329504
# poutcome           41492
# emp.var.rate      329504
# cons.price.idx    329504
# cons.conf.idx     329504
# euribor3m         329504
# nr.employed       329504
# y                  41415
# dtype: int64

# %%
bank_full.memory_usage(deep=True).sum()
# Out:
# 3753617
