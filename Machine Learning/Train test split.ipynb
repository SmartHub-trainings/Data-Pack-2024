# %%
from sklearn.linear_model import LinearRegression
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score

# %%
weight_on_age_linear_model=LinearRegression()

# %%
age=np.array([20,17,30,35,40])
weight=np.array([65,50,90,80,64])
# weight_on_age_linear_model.fit(age,weight)

# %%
age
# Out:
# array([20, 17, 30, 35, 40])

# %%
weight
# Out:
# array([65, 50, 90, 80, 64])

# %%
age=age.reshape(-1,1)

# %%
age
# Out:
# array([[20],
#        [17],
#        [30],
#        [35],
#        [40]])

# %%
weight_on_age_linear_model.fit(age,weight)
# Out:
# LinearRegression()

# %%
weight_on_age_linear_model.intercept_
# Out:
# 47.56873032528857

# %%
weight_on_age_linear_model.coef_
# Out:
# array([0.78279119])

# %%
weight_on_age_linear_model.predict(age)
# Out:
# array([63.22455404, 60.87618048, 71.0524659 , 74.96642183, 78.88037775])

# %%
predicted_weights=weight_on_age_linear_model.predict(age)
mse=mean_squared_error(weight,predicted_weights)

# %%
rmse=mse**0.5

# %%
rmse
# Out:
# 12.059976037939576

# %%
r2_score(predicted_weights,weight)
# Out:
# -2.1132797619475467

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(age,weight)

# %%
plt.scatter(age,predicted_weights)

# %%
plt.scatter(age,weight)
plt.scatter(age,predicted_weights)

# %%
 # Traing and test on entire datasets

# %% [markdown]
# # Train-test split

# %%
from sklearn.datasets import load_boston

# %%
dataset=load_boston()

# %%
print(dataset.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
y=dataset.target

# %%
X=dataset.data

# %%
X.shape
# Out:
# (506, 13)

# %%
dataset.feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
X[0]
# Out:
# array([6.320e-03, 1.800e+01, 2.310e+00, 0.000e+00, 5.380e-01, 6.575e+00,
#        6.520e+01, 4.090e+00, 1.000e+00, 2.960e+02, 1.530e+01, 3.969e+02,
#        4.980e+00])

# %%
X_crim=X[:,0]

# %%
X[:,0].shape
# Out:
# (506,)

# %%
y
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %%
X_crim
# Out:
# array([6.32000e-03, 2.73100e-02, 2.72900e-02, 3.23700e-02, 6.90500e-02,
#        2.98500e-02, 8.82900e-02, 1.44550e-01, 2.11240e-01, 1.70040e-01,
#        2.24890e-01, 1.17470e-01, 9.37800e-02, 6.29760e-01, 6.37960e-01,
#        6.27390e-01, 1.05393e+00, 7.84200e-01, 8.02710e-01, 7.25800e-01,
#        1.25179e+00, 8.52040e-01, 1.23247e+00, 9.88430e-01, 7.50260e-01,
#        8.40540e-01, 6.71910e-01, 9.55770e-01, 7.72990e-01, 1.00245e+00,
#        1.13081e+00, 1.35472e+00, 1.38799e+00, 1.15172e+00, 1.61282e+00,
#        6.41700e-02, 9.74400e-02, 8.01400e-02, 1.75050e-01, 2.76300e-02,
#        3.35900e-02, 1.27440e-01, 1.41500e-01, 1.59360e-01, 1.22690e-01,
#        1.71420e-01, 1.88360e-01, 2.29270e-01, 2.53870e-01, 2.19770e-01,
#        8.87300e-02, 4.33700e-02, 5.36000e-02, 4.98100e-02, 1.36000e-02,
#        1.31100e-02, 2.05500e-02, 1.43200e-02, 1.54450e-01, 1.03280e-01,
#        1.49320e-01, 1.71710e-01, 1.10270e-01, 1.26500e-01, 1.95100e-02,
# ...

# %%
plt.scatter(X_crim,y)

# %%
X.shape
# Out:
# (506, 13)

# %%
for i in range(X.shape[1]):
    X_use=X[:,i]
    plt.scatter(X_use,y)
    print()

# %%
fig, axes = plt.subplots(1, X.shape[1], figsize=(15, 5))

for i in range(X.shape[1]):
    X_use = X[:, i]
    axes[i].scatter(X_use, y)
    axes[i].set_title(f"Feature {i+1}")

# %%
fig, axes = plt.subplots(4, 4, figsize=(15, 10))
axes = axes.flatten()  # Flatten in case it's a 2D array

for i in range(X.shape[1]):
    X_use = X[:, i]
    print(dataset.feature_names[i])
    print(i)
    print(np.corrcoef(X_use,y))
    print(str("="*40)+"\n")
    
    axes[i].scatter(X_use, y)
    axes[i].set_title(f"Feature {i+1}")
# Out:
# CRIM
# 0
# [[ 1.         -0.38830461]
#  [-0.38830461  1.        ]]
# ...
#
# ZN
# 1
# [[1.         0.36044534]
#  [0.36044534 1.        ]]
# ...
#
# INDUS
# 2
# [[ 1.         -0.48372516]
#  [-0.48372516  1.        ]]
# ...
#
# CHAS
# 3
# [[1.         0.17526018]
#  [0.17526018 1.        ]]
# ...
#
# NOX
# 4
# [[ 1.         -0.42732077]
#  [-0.42732077  1.        ]]
# ...
#
# RM
# 5
# [[1.         0.69535995]
#  [0.69535995 1.        ]]
# ...
#
# AGE
# 6
# [[ 1.         -0.37695457]
#  [-0.37695457  1.        ]]
# ...
#
# DIS
# 7
# [[1.         0.24992873]
#  [0.24992873 1.        ]]
# ...
#
# RAD
# 8
# [[ 1.         -0.38162623]
#  [-0.38162623  1.        ]]
# ...
#
# TAX
# 9
# [[ 1.         -0.46853593]
#  [-0.46853593  1.        ]]
# ...
#
# PTRATIO
# 10
# [[ 1.         -0.50778669]
#  [-0.50778669  1.        ]]
# ...
#
# B
# 11
# [[1.         0.33346082]
#  [0.33346082 1.        ]]
# ...
#
# LSTAT
# 12
# [[ 1.         -0.73766273]
#  [-0.73766273  1.        ]]
# ...

# %%
X_rm=X[:,5]

# %%
X_rm=X_rm.reshape(-1,1)

# %%
boston_model_rm =LinearRegression()
boston_model_rm.fit(X_rm,y)
print(boston_model_rm.coef_)
print(boston_model_rm.intercept_)
# Out:
# [9.10210898]
# -34.67062077643857

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(X_rm,y)

# %%
X_train.shape
# Out:
# (379, 1)

# %%
X_test.shape
# Out:
# (127, 1)

# %%
127/506
# Out:
# 0.2509881422924901

# %%
379/506
# Out:
# 0.7490118577075099

# %%
boston_model_rm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred= boston_model_rm.predict(X_test)
r2_score(y_test,y_pred)*100
# Out:
# 45.12948223487642
