# %%
import pandas as pd

# %%
drinks = pd.read_csv("../datasets/drinks.csv")

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drinks.sort_values(["total_litres_of_pure_alcohol"])
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 0       Afghanistan              0                0              0
# 147      San Marino              0                0              0
# 128        Pakistan              0                0              0
# 46      North Korea              0                0              0
# 13       Bangladesh              0                0              0
# ..              ...            ...              ...            ...
# 45   Czech Republic            361              170            134
# 68          Grenada            199              438             28
# 3           Andorra            245              138            312
# 98        Lithuania            343              244             56
# 15          Belarus            142              373             42
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 147                           0.0        EU
# ...

# %%
drinks.sort_values(["total_litres_of_pure_alcohol"],ascending=False)
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 15          Belarus            142              373             42
# 98        Lithuania            343              244             56
# 3           Andorra            245              138            312
# 68          Grenada            199              438             28
# 45   Czech Republic            361              170            134
# ..              ...            ...              ...            ...
# 79             Iran              0                0              0
# 90           Kuwait              0                0              0
# 128        Pakistan              0                0              0
# 97            Libya              0                0              0
# 0       Afghanistan              0                0              0
#
#      total_litres_of_pure_alcohol continent
# 15                           14.4        EU
# 98                           12.9        EU
# ...

# %%
drinks.sort_values(["total_litres_of_pure_alcohol"],ascending=False).iloc[0]
# Out:
# country                         Belarus
# beer_servings                       142
# spirit_servings                     373
# wine_servings                        42
# total_litres_of_pure_alcohol       14.4
# continent                            EU
# Name: 15, dtype: object

# %%
drinks.groupby("continent").sum()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  3258              866            862
# AS                  1630             2677            399
# EU                  8720             5965           6400
# OC                  1435              935            570
# SA                  2101             1377            749
#
#            total_litres_of_pure_alcohol
# continent
# AF                                159.4
# AS                                 95.5
# EU                                387.8
# OC                                 54.1
# SA                                 75.7

# %%
drinks.groupby("continent").sum().total_litres_of_pure_alcohol.sort_values(ascending=False)
# Out:
# continent
# EU    387.8
# AF    159.4
# AS     95.5
# SA     75.7
# OC     54.1
# Name: total_litres_of_pure_alcohol, dtype: float64

# %%
continents_total=drinks.groupby("continent").sum().total_litres_of_pure_alcohol

# %%
continents_total.plot(kind="bar",title="Total alcohol consumption by continents")
# Out:
# <AxesSubplot:title={'center':'Total alcohol consumption by continents'}, xlabel='continent'>

# %%
drinks.continent.unique()
# Out:
# array(['AS', 'EU', 'AF', nan, 'SA', 'OC'], dtype=object)

# %%
drinks.continent.unique()

# %%
asia_drinks =drinks[drinks.continent=="AS"]

# %%
asia_consumption=asia_drinks.total_litres_of_pure_alcohol.sum()

# %%
asia_consumption
# Out:
# 95.49999999999999

# %%
for continent in drinks.continent.unique():
    contient_drinks =drinks[drinks.continent==continent]
    continent_consumption=contient_drinks.total_litres_of_pure_alcohol.sum()
    print(f"{continent}: {continent_consumption}")
# Out:
# AS: 95.49999999999999
# EU: 387.7999999999999
# AF: 159.4
# nan: 0.0
# SA: 75.7
# OC: 54.099999999999994

# %%
consumptions=[]
for continent in drinks.continent.unique():
    contient_drinks =drinks[drinks.continent==continent]
    continent_consumption=contient_drinks.total_litres_of_pure_alcohol.sum()
    print(f"{continent}: {continent_consumption}")
    consumptions.append(continent_consumption)
print(sorted(consumptions))
# Out:
# AS: 95.49999999999999
# EU: 387.7999999999999
# AF: 159.4
# nan: 0.0
# SA: 75.7
# OC: 54.099999999999994
# [0.0, 54.099999999999994, 75.7, 95.49999999999999, 159.4, 387.7999999999999]

# %%
drinks.sort_values(["continent"])
# Out:
#                           country  beer_servings  spirit_servings  \
# 192                      Zimbabwe             64               18
# 152                    Seychelles            157               25
# 150                       Senegal              9                1
# 95                        Lesotho             82               29
# 142                        Rwanda             43                2
# ..                            ...            ...              ...
# 143             St. Kitts & Nevis            194              205
# 144                     St. Lucia            171              315
# 145  St. Vincent & the Grenadines            120              221
# 174             Trinidad & Tobago            197              156
# 184                           USA            249              158
#
#      wine_servings  total_litres_of_pure_alcohol continent
# 192              4                           4.7        AF
# ...

# %%
drinks.sort_values(["country"])
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
drinks.sort_values(["continent","country"])
# Out:
#                           country  beer_servings  spirit_servings  \
# 2                         Algeria             25                0
# 4                          Angola            217               57
# 18                          Benin             34                4
# 22                       Botswana            173               35
# 26                   Burkina Faso             25                7
# ..                            ...            ...              ...
# 143             St. Kitts & Nevis            194              205
# 144                     St. Lucia            171              315
# 145  St. Vincent & the Grenadines            120              221
# 174             Trinidad & Tobago            197              156
# 184                           USA            249              158
#
#      wine_servings  total_litres_of_pure_alcohol continent
# 2               14                           0.7        AF
# ...

# %%
drinks.set_index(["country"])
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
# ...                    ...              ...            ...
# Venezuela              333              100              3
# Vietnam                111                2              1
# Yemen                    6                0              0
# Zambia                  32               19              4
# Zimbabwe                64               18              4
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0        AS
# Albania                               4.9        EU
# Algeria                               0.7        AF
# ...

# %%
drinks.set_index(["continent"])
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# continent
# AS         Afghanistan              0                0              0
# EU             Albania             89              132             54
# AF             Algeria             25                0             14
# EU             Andorra            245              138            312
# AF              Angola            217               57             45
# ...                ...            ...              ...            ...
# SA           Venezuela            333              100              3
# AS             Vietnam            111                2              1
# AS               Yemen              6                0              0
# AF              Zambia             32               19              4
# AF            Zimbabwe             64               18              4
#
#            total_litres_of_pure_alcohol
# continent
# AS                                  0.0
# ...

# %%
drinks.set_index(["continent","country"])
# Out:
#                        beer_servings  spirit_servings  wine_servings  \
# continent country
# AS        Afghanistan              0                0              0
# EU        Albania                 89              132             54
# AF        Algeria                 25                0             14
# EU        Andorra                245              138            312
# AF        Angola                 217               57             45
# ...                              ...              ...            ...
# SA        Venezuela              333              100              3
# AS        Vietnam                111                2              1
#           Yemen                    6                0              0
# AF        Zambia                  32               19              4
#           Zimbabwe                64               18              4
#
#                        total_litres_of_pure_alcohol
# continent country
# ...

# %%
drinks.set_index(["continent","country"]).sort_index()
# Out:
#                                         beer_servings  spirit_servings  \
# continent country
# AF        Algeria                                  25                0
#           Angola                                  217               57
#           Benin                                    34                4
#           Botswana                                173               35
#           Burkina Faso                             25                7
# ...                                               ...              ...
# NaN       St. Kitts & Nevis                       194              205
#           St. Lucia                               171              315
#           St. Vincent & the Grenadines            120              221
#           Trinidad & Tobago                       197              156
#           USA                                     249              158
#
#                                         wine_servings  \
# continent country
# ...
