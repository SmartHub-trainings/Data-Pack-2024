# %%
import pandas as pd

# %%
drinks = pd.read_csv("../datasets/drinks.csv")

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
drinks =drinks.sort_values(["continent","country"])

# %%
drinks.sort_values(["total_litres_of_pure_alcohol"],ascending=False)
# Out:
#               country  beer_servings  spirit_servings  wine_servings  \
# 15            Belarus            142              373             42
# 98          Lithuania            343              244             56
# 3             Andorra            245              138            312
# 68            Grenada            199              438             28
# 45     Czech Republic            361              170            134
# ..                ...            ...              ...            ...
# 90             Kuwait              0                0              0
# 79               Iran              0                0              0
# 158           Somalia              0                0              0
# 0         Afghanistan              0                0              0
# 106  Marshall Islands              0                0              0
#
#      total_litres_of_pure_alcohol continent
# 15                           14.4        EU
# 98                           12.9        EU
# ...

# %%
drinks.groupby(["continent"]).sum().sort_values(["total_litres_of_pure_alcohol"],ascending=False)
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# EU                  8720             5965           6400
# AF                  3258              866            862
# AS                  1630             2677            399
# SA                  2101             1377            749
# OC                  1435              935            570
#
#            total_litres_of_pure_alcohol
# continent
# EU                                387.8
# AF                                159.4
# AS                                 95.5
# SA                                 75.7
# OC                                 54.1
