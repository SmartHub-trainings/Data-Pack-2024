# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
x=np.linspace(1,100)

# %%
x.shape
# Out:
# (50,)

# %%
x
# Out:
# array([  1.        ,   3.02040816,   5.04081633,   7.06122449,
#          9.08163265,  11.10204082,  13.12244898,  15.14285714,
#         17.16326531,  19.18367347,  21.20408163,  23.2244898 ,
#         25.24489796,  27.26530612,  29.28571429,  31.30612245,
#         33.32653061,  35.34693878,  37.36734694,  39.3877551 ,
#         41.40816327,  43.42857143,  45.44897959,  47.46938776,
#         49.48979592,  51.51020408,  53.53061224,  55.55102041,
#         57.57142857,  59.59183673,  61.6122449 ,  63.63265306,
#         65.65306122,  67.67346939,  69.69387755,  71.71428571,
#         73.73469388,  75.75510204,  77.7755102 ,  79.79591837,
#         81.81632653,  83.83673469,  85.85714286,  87.87755102,
#         89.89795918,  91.91836735,  93.93877551,  95.95918367,
#         97.97959184, 100.        ])

# %%
y_sin=np.sin(x)

# %%
y_sin
# Out:
# array([ 0.84147098,  0.1208881 , -0.94655078,  0.7018841 ,  0.33645069,
#        -0.99433779,  0.5278595 ,  0.53550545, -0.99333794,  0.32793565,
#         0.7082858 , -0.9436003 ,  0.11192174,  0.84631435, -0.84756522,
#        -0.10958357,  0.94281876, -0.70994463, -0.3257122 ,  0.99306408,
#        -0.53749084, -0.52585986,  0.99458504, -0.33866525, -0.70020639,
#         0.94730702, -0.12322315, -0.84019752,  0.85354968,  0.09826485,
#        -0.93896463,  0.71791322,  0.31493152, -0.99166176,  0.54705258,
#         0.51614618, -0.99570333,  0.34935098,  0.69203629, -0.95089105,
#         0.1345086 ,  0.83397187, -0.8594236 , -0.08693341,  0.9349889 ,
#        -0.72578883, -0.30411005,  0.99013101, -0.55654346, -0.50636564])

# %%
plt.scatter(x,y_sin)

# %%
plt.plot(x,y_sin)

# %%
x=np.linspace(1,100,100)
y_sin=np.sin(x)
plt.plot(x,y_sin)

# %%
x=np.linspace(1,100,1000)
y_sin=np.sin(x)
plt.plot(x,y_sin)

# %%
x=np.linspace(0,50,1000)
y_sin=np.sin(x)
plt.plot(x,y_sin)

# %%
x=np.linspace(0,50,1000)
y_cos=np.cos(x)
plt.plot(x,y_cos)

# %%
x=np.linspace(0,50,500)
y_cos=np.cos(x)
plt.scatter(x,y_cos,marker="x")

# %%
x=np.linspace(0,50,1000)
y_cos=np.cos(x)
plt.plot(x,y_cos)
plt.xlabel("X values")
plt.ylabel("cosine")
# Out:
# Text(0, 0.5, 'cosine')

# %%
x=np.linspace(0,50,1000)
y_cos=np.cos(x)
plt.plot(x,y_cos,color="r")
plt.xlabel("X values")
plt.ylabel("cosine")
# Out:
# Text(0, 0.5, 'cosine')

# %%
x=np.linspace(0,50,1000)
y_cos=np.cos(x)
plt.plot(x,y_cos,color="r")
plt.xlabel("X values")
plt.ylabel("cosine")
plt.title("Graph of cosine function")
# Out:
# Text(0.5, 1.0, 'Graph of cosine function')

# %%
x=np.linspace(0,50,1000)
y_cos=np.cos(x)
plt.plot(x,y_cos,color="r")
plt.xlabel("X values")
plt.ylabel("cosine")
plt.title("Graph of cosine function")
plt.grid()

# %%
x=np.linspace(0,50,1000)
y_cos=np.cos(x)
y_sin=np.sin(x)
plt.plot(x,y_cos)
plt.plot(x,y_sin)

# %%
x=np.linspace(0,50,1000)
y_cos=np.cos(x)
y_sin=np.sin(x)
plt.plot(x,y_cos)
plt.plot(x,y_sin)
plt.legend(labels=["Cosine","Sine"])

# %%
x=np.linspace(0,50,1000)
y_cos=np.cos(x)
y_sin=np.sin(x)
plt.plot(x,y_cos)
plt.plot(x,y_sin)
plt.legend(labels=["Cosine","Sine"])

# %%
np.random.seed(10)
ages=np.random.randint(16,40,40)
weights=np.random.randint(16,40,40)

# %%
ages
# Out:
# array([25, 20, 31, 16, 33, 32, 33, 24, 25, 16, 26, 24, 38, 20, 35, 32, 20,
#        31, 27, 38])

# %%
weights
# Out:
# array([27, 17, 24, 20, 30, 33, 35, 38, 29, 21, 29, 35, 29, 38, 28, 17, 20,
#        34, 29, 38])

# %%
plt.scatter(ages,weights)

# %%
np.random.seed(10)
number_of_values=100
ages=np.random.randint(16,40,number_of_values)
weights=np.random.randint(16,40,number_of_values)
plt.scatter(ages,weights,s=100)

# %%
np.random.seed(10)
number_of_values=100
ages=np.random.randint(16,40,number_of_values)
weights=np.random.randint(16,40,number_of_values)
plt.scatter(ages,weights,s=300,alpha=0.4)

# %%
ages
# Out:
# array([25, 20, 31, 16, 33, 32, 33, 24, 25, 16, 26, 24, 38, 20, 35, 32, 20,
#        31, 27, 38, 27, 17, 24, 20, 30, 33, 35, 38, 29, 21, 29, 35, 29, 38,
#        28, 17, 20, 34, 29, 38, 39, 27, 26, 25, 31, 34, 32, 38, 23, 27, 33,
#        30, 23, 27, 17, 36, 16, 28, 21, 20, 23, 34, 28, 38, 18, 24, 31, 29,
#        31, 22, 38, 37, 26, 38, 27, 32, 28, 16, 38, 33, 31, 28, 24, 26, 29,
#        27, 17, 34, 29, 24, 25, 21, 16, 34, 39, 19, 32, 36, 34, 32])

# %%
plt.boxplot(ages)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f77b98da160>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f77b98da880>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f77b98cbd90>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f77b98dafa0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f77b98e5370>],
#  'means': []}

# %%
plt.boxplot(ages);

# %%
ages.mean()
# Out:
# 28.18

# %%
ages.std()
# Out:
# 6.544279945112374

# %%
ages[5]=300

# %%
ages
# Out:
# array([ 25,  20,  31,  16,  33, 700,  33,  24,  25,  16,  26,  24,  38,
#         20,  35,  32,  20,  31,  27,  38,  27,  17,  24,  20,  30,  33,
#         35,  38,  29,  21,  29,  35,  29,  38,  28,  17,  20,  34,  29,
#         38,  39,  27,  26,  25,  31,  34,  32,  38,  23,  27,  33,  30,
#         23,  27,  17,  36,  16,  28,  21,  20,  23,  34,  28,  38,  18,
#         24,  31,  29,  31,  22,  38,  37,  26,  38,  27,  32,  28,  16,
#         38,  33,  31,  28,  24,  26,  29,  27,  17,  34,  29,  24,  25,
#         21,  16,  34,  39,  19,  32,  36,  34,  32])

# %%
ages.mean()
# Out:
# 31.86

# %%
ages.std()
# Out:
# 37.57180325723001

# %%
plt.boxplot(ages);

# %%
ages.dtype="float16"

# %%
ages
# Out:
# array([1.49e-06, 0.00e+00, 0.00e+00, 0.00e+00, 1.19e-06, 0.00e+00,
#        0.00e+00, 0.00e+00, 1.85e-06, 0.00e+00, 0.00e+00, 0.00e+00,
#        9.54e-07, 0.00e+00, 0.00e+00, 0.00e+00, 1.97e-06, 0.00e+00,
#        0.00e+00, 0.00e+00, 1.79e-05, 0.00e+00, 0.00e+00, 0.00e+00,
#        1.97e-06, 0.00e+00, 0.00e+00, 0.00e+00, 1.43e-06, 0.00e+00,
#        0.00e+00, 0.00e+00, 1.49e-06, 0.00e+00, 0.00e+00, 0.00e+00,
#        9.54e-07, 0.00e+00, 0.00e+00, 0.00e+00, 1.55e-06, 0.00e+00,
#        0.00e+00, 0.00e+00, 1.43e-06, 0.00e+00, 0.00e+00, 0.00e+00,
#        2.26e-06, 0.00e+00, 0.00e+00, 0.00e+00, 1.19e-06, 0.00e+00,
#        0.00e+00, 0.00e+00, 2.09e-06, 0.00e+00, 0.00e+00, 0.00e+00,
#        1.91e-06, 0.00e+00, 0.00e+00, 0.00e+00, 1.19e-06, 0.00e+00,
#        0.00e+00, 0.00e+00, 1.85e-06, 0.00e+00, 0.00e+00, 0.00e+00,
#        1.61e-06, 0.00e+00, 0.00e+00, 0.00e+00, 2.26e-06, 0.00e+00,
#        0.00e+00, 0.00e+00, 1.61e-06, 0.00e+00, 0.00e+00, 0.00e+00,
# ...
