# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)
ages = np.random.randint(16,70,40)

# %%
ages
# Out:
# array([54, 67, 44, 30, 58, 23, 36, 54, 34, 38, 26, 26, 39, 68, 51, 55, 39,
#        18, 37, 68, 17, 39, 59, 45, 53, 17, 36, 48, 27, 37, 59, 40, 64, 42,
#        57, 43, 31, 30, 62, 66])

# %%
plt.hist(ages)
# Out:
# (array([3., 4., 3., 5., 6., 3., 2., 5., 4., 5.]),
#  array([17. , 22.1, 27.2, 32.3, 37.4, 42.5, 47.6, 52.7, 57.8, 62.9, 68. ]),
#  <BarContainer object of 10 artists>)

# %%
ages.sort()

# %%
ages
# Out:
# array([17, 17, 18, 23, 26, 26, 27, 30, 30, 31, 34, 36, 36, 37, 37, 38, 39,
#        39, 39, 40, 42, 43, 44, 45, 48, 51, 53, 54, 54, 55, 57, 58, 59, 59,
#        62, 64, 66, 67, 68, 68])

# %%
plt.hist(ages,bins=15);

# %%
plt.hist(ages,bins=[15,20,40,65,80,100]);

# %%
# Students expenses

# %%
expenses = [20,45,56,78,86,23,34]
days = ["mon","tues","wed","thur","fri","sat","sun"]
plt.bar(days,expenses)
# Out:
# <BarContainer object of 7 artists>

# %%
ola_expenses = np.random.randint(1,100,7)
mike_expenses = np.random.randint(1,100,7)
days = ["mon","tues","wed","thur","fri","sat","sun"]
plt.bar(days,ola_expenses)
plt.bar(days,mike_expenses)
# Out:
# <BarContainer object of 7 artists>

# %%
ola_expenses = np.random.randint(1,100,7)
mike_expenses = np.random.randint(1,100,7)
days = ["mon","tues","wed","thur","fri","sat","sun"]
plt.bar(days,ola_expenses)
plt.bar(days,mike_expenses)
plt.legend(labels=["Ola","Mike"])

# %%
days = ["mon","tues","wed","thur","fri","sat","sun"]
plt.bar(days,mike_expenses)
plt.bar(days,ola_expenses)

plt.legend(labels=["Ola","Mike"])

# %%
days = ["mon","tues","wed","thur","fri","sat","sun"]
plt.bar(days,mike_expenses,label="Mike")
plt.bar(days,ola_expenses,label="ola")

plt.legend()

# %%
days = ["mon","tues","wed","thur","fri","sat","sun"]
plt.bar(days,ola_expenses,label="ola")
plt.bar(days,mike_expenses,label="Mike")


plt.legend()

# %%
plt.stackplot(ola_expenses)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_3135/257838921.py in <module>
# ----> 1 plt.stackplot(ola_expenses)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in stackplot(x, labels, colors, baseline, data, *args, **kwargs)
#    3121         x, *args, labels=(), colors=None, baseline='zero', data=None,
#    3122         **kwargs):
# -> 3123     return gca().stackplot(
#    3124         x, *args, labels=labels, colors=colors, baseline=baseline,
#    3125         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
# ...

# %%
plt.stackplot(days,ola_expenses)

# %%
ola_expenses
# Out:
# array([50,  4,  2,  6, 54,  4, 54])

# %%
plt.bar(days,ola_expenses)
# Out:
# <BarContainer object of 7 artists>

# %%
plt.stackplot(days,ola_expenses,mike_expenses)

# %%
mike_expenses
# Out:
# array([93, 63, 18, 90, 44, 34, 74])

# %%
plt.stackplot(days,ola_expenses,mike_expenses)
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
plt.stackplot(days,ola_expenses,mike_expenses)
plt.bar(days,np.zeros(7),label="Ola")
plt.bar(days,np.zeros(7),label="Mike")

plt.legend()

# %%
plt.stackplot(days,ola_expenses,mike_expenses,labels=["Ola","Mike"])
plt.legend()

# %%
import numpy as np

# %%
np.random.randint(1,4,6)
# Out:
# array([1, 1, 1, 3, 1, 3])
